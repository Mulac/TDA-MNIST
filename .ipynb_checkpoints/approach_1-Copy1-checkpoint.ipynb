# %% [markdown]
# Code adapted from the new fastai book.  By Jeremy Howard who runs the best deep learning course I've ever taken.  Chapter 04 will contain pretty much everything we need and is a great starting point!
#
# https://github.com/fastai/fastbook

# %%
from fastai.vision import *

# %% [markdown]
# ## Data preperation

# %%
path = untar_data(URLs.MNIST)

# %% [markdown]
# #### TODO: Augment Data
# test effects of different transforms

# %%
tfms = get_transforms()

# %% [markdown]
# #### Load downloaded data into a databunch

# %%
data = (ImageList.from_folder(path)
        .split_by_folder(train='training', valid='testing')
        .label_from_folder()
        .databunch()
        .normalize())

# %%
data.show_batch(rows=4, figsize=(6,6))

# %% [markdown]
# ## Create and train a CNN model
#  Uses the resnet18 architecture ( 18 hidden layers )
#  and the cross_entropy loss function

# %%
learn = cnn_learner(data, models.resnet18, pretrained=False,
                    loss_func=F.cross_entropy, metrics=accuracy)
learn.fit_one_cycle(1, 0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.102373</td>
#       <td>0.048413</td>
#       <td>0.984500</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()
interp.plot_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-c35126e66c7f> in <module>
#       1 interp.plot_confusion_matrix()
# ----> 2 interp.plot_loss()
#
# AttributeError: 'ClassificationInterpretation' object has no attribute 'plot_loss'
